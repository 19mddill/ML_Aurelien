# %% [markdown]
# <a href="https://colab.research.google.com/github/19mddill/ML_Aurelien/blob/main/linear_model_training_principles.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
np.random.seed(42)
m = 100
X = 2 * np.random.rand(m,1)
y = 4 + 3 * X + np.random.randn(m,1)
# extra code – generates and saves Figure 4–1

import matplotlib.pyplot as plt

plt.figure(figsize=(6, 4))
plt.plot(X, y, "b.")
plt.xlabel("$x_1$")
plt.ylabel("$y$", rotation=0)
plt.axis([0, 2, 0, 15])
plt.grid()
plt.show()

# %%
X,y
# Out:
# (array([[0.74908024],
#         [1.90142861],
#         [1.46398788],
#         [1.19731697],
#         [0.31203728],
#         [0.31198904],
#         [0.11616722],
#         [1.73235229],
#         [1.20223002],
#         [1.41614516],
#         [0.04116899],
#         [1.9398197 ],
#         [1.66488528],
#         [0.42467822],
#         [0.36364993],
#         [0.36680902],
#         [0.60848449],
#         [1.04951286],
#         [0.86389004],
#         [0.58245828],
#         [1.22370579],
#         [0.27898772],
#         [0.5842893 ],
#         [0.73272369],
#         [0.91213997],
#         [1.57035192],
#         [0.39934756],
#         [1.02846888],
#         [1.18482914],
#         [0.09290083],
#         [1.2150897 ],
#         [0.34104825],
#         [0.13010319],
#         [1.89777107],
#         [1.93126407],
#         [1.6167947 ],
#         [0.60922754],
#         [0.19534423],
#         [1.36846605],
#         [0.88030499],
#         [0.24407647],
# ...

# %%
from sklearn.preprocessing import add_dummy_feature

X_b = add_dummy_feature(X)

# %%
X_b
# Out:
# array([[1.        , 0.74908024],
#        [1.        , 1.90142861],
#        [1.        , 1.46398788],
#        [1.        , 1.19731697],
#        [1.        , 0.31203728],
#        [1.        , 0.31198904],
#        [1.        , 0.11616722],
#        [1.        , 1.73235229],
#        [1.        , 1.20223002],
#        [1.        , 1.41614516],
#        [1.        , 0.04116899],
#        [1.        , 1.9398197 ],
#        [1.        , 1.66488528],
#        [1.        , 0.42467822],
#        [1.        , 0.36364993],
#        [1.        , 0.36680902],
#        [1.        , 0.60848449],
#        [1.        , 1.04951286],
#        [1.        , 0.86389004],
#        [1.        , 0.58245828],
#        [1.        , 1.22370579],
#        [1.        , 0.27898772],
#        [1.        , 0.5842893 ],
#        [1.        , 0.73272369],
#        [1.        , 0.91213997],
#        [1.        , 1.57035192],
#        [1.        , 0.39934756],
#        [1.        , 1.02846888],
# ...

# %% [markdown]
# # normal equation

# %%
theta_best_vector = np.linalg.inv(X_b.T @ X_b) @ X_b.T @ y
theta_best_vector
# Out:
# array([[4.21509616],
#        [2.77011339]])

# %%
X_new = np.array([[0],[2]])
X_new_b = add_dummy_feature(X_new)

# %%
y_predict = X_new_b @ theta_best_vector
y_predict
# Out:
# array([[4.21509616],
#        [9.75532293]])

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(6, 4))
plt.plot(X, y, "b.")
plt.plot(X_new, y_predict, "r-", linewidth=2)
